# %%
import matplotlib.pyplot as plt

# %%
# Epochs
epochs = list(range(10, 101, 10))

# Training and Testing Loss
train_loss = [3.5868, 3.4604, 3.3713, 3.2811, 3.1518, 3.0205, 2.9239, 2.8621, 2.8197, 2.7972]
test_loss = [4.9161, 4.8335, 4.7586, 4.6195, 4.3770, 4.1247, 3.9294, 3.8026, 3.7287, 3.6943]

# Plotting
plt.figure(figsize=(15, 6))

# Training Loss Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Training Loss', marker='o', color="orange", linewidth=5)
plt.title('Training Loss of Sorting Regression Model', fontsize=20)
plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.grid(True)
plt.legend(fontsize=18)

# Test Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, test_loss, label='Testing Loss', marker='o', color="orange", linewidth=5)
plt.title('Testing Loss of Sorting Regression Model', fontsize=20)
plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.grid(True)
plt.legend(fontsize=18)

plt.tight_layout()
# plt.show()
plt.savefig('figures/sorting_regression_loss.png', dpi=300)

# %%
epochs = list(range(1, 31))
no_sorting_lr001_train_loss = [2.4212, 2.0149, 1.9739, 1.9263, 1.8881, 1.8488, 1.8072, 1.7605, 1.7003, 1.6283, 1.5545, 1.4602, 1.3603, 1.2576, 1.1611, 1.0672, 0.9757, 0.8862, 0.8045, 0.7402, 0.6712, 0.6052, 0.5542, 0.5031, 0.4644, 0.4194, 0.3864, 0.3516, 0.3212, 0.3001]
no_sorting_lr001_test_loss = [2.0338, 2.0310, 2.0354, 2.0449, 2.0477, 2.0808, 2.0889, 2.1166, 2.1957, 2.2238, 2.2849, 2.3686, 2.4407, 2.5924, 2.6431, 2.7948, 2.8788, 2.8665, 2.9218, 3.0725, 3.1024, 3.1333, 3.2123, 3.4092, 3.3830, 3.6310, 3.4962, 3.6554, 3.4923, 3.5252]

# %%
no_sorting_lr00005_train_loss = [4.6114, 2.0908, 2.0563, 2.0442, 2.0361, 2.0302, 2.0238, 2.0197, 2.0153, 2.0098, 2.0051, 2.0017, 1.9967, 1.9939, 1.9890, 1.9854, 1.9809, 1.9780, 1.9735, 1.9702, 1.9656, 1.9613, 1.9581, 1.9543, 1.9505, 1.9461, 1.9421, 1.9383, 1.9339, 1.9284]
no_sorting_lr00005_test_loss = [2.1893, 2.0467, 2.0353, 2.0295, 2.0266, 2.0233, 2.0216, 2.0201, 2.0188, 2.0180, 2.0177, 2.0170, 2.0162, 2.0160, 2.0159, 2.0156, 2.0169, 2.0151, 2.0155, 2.0181, 2.0163, 2.0161, 2.0158, 2.0160, 2.0166, 2.0171, 2.0199, 2.0178, 2.0211, 2.0196]

# %%
# with sorting regularization-1.0  lr=0.001

sorting_lr001_train_loss = [3.2018, 2.1828, 2.1426, 2.1278, 2.1345, 2.1095, 2.0964, 2.0848, 2.0851, 2.0724, 2.0627, 2.0569, 2.0497, 2.0533, 2.0394, 2.0417, 2.0361, 2.0313, 2.0260, 2.0236, 2.0183, 2.0180, 2.0144, 2.0123, 2.0126, 2.0135, 2.0116, 2.0142, 2.0123, 2.0126]
sorting_lr001_test_loss = [2.1718, 2.2622, 2.0971, 2.0733, 2.0503, 2.0878, 2.0365, 2.0391, 2.0747, 2.0969, 2.0228, 2.0079, 2.0121, 2.0037, 1.9984, 1.9897, 1.9935, 1.9840, 1.9849, 1.9758, 1.9754, 1.9759, 1.9728, 1.9726, 1.9731, 1.9730, 1.9759, 1.9725, 1.9746, 1.9724]

# %%
# regularization 1.0 lr 0.00005

sorting_lr00005_train_loss = [7.0490, 3.9357, 2.1666, 2.1021, 2.0861, 2.0686, 2.0647, 2.0590, 2.0516, 2.0551, 2.0615, 2.0583, 2.0514, 2.0480, 2.0517, 2.0493, 2.0435, 2.0501, 2.0500, 2.0494, 2.0431, 2.0417, 2.0443, 2.0463, 2.0477, 2.0433, 2.0396, 2.0418, 2.0381, 2.0409]
sorting_lr00005_test_loss = [6.0780, 2.2628, 2.0825, 2.0589, 2.0435, 2.0360, 2.0289, 2.0255, 2.0199, 2.0173, 2.0175, 2.0142, 2.0131, 2.0125, 2.0134, 2.0126, 2.0128, 2.0094, 2.0094, 2.0090, 2.0071, 2.0070, 2.0087, 2.0067, 2.0058, 2.0060, 2.0045, 2.0038, 2.0048, 2.0037]

# %%
# Train Loss Comparison
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

axes.plot(epochs, no_sorting_lr001_train_loss, label='w/o SortingLayer Training Loss, lr=0.001', marker='x', color='blue', linewidth=1)
axes.plot(epochs, sorting_lr001_train_loss, label='w SortingLayer Training Loss, lr=0.001', marker='o', color='red', linewidth=2)
axes.plot(epochs, no_sorting_lr00005_train_loss, label='w/o SortingLayer Training Loss lr=0.00005', marker='x', color='green', linewidth=1)
axes.plot(epochs, sorting_lr00005_train_loss, label='w SortingLayer Training Loss, lr=0.00005', marker='o', color='purple', linewidth=2)
axes.set_title('Training Loss comparison of RS model w and w/o SortingLayer', fontsize=20)
axes.set_xlabel('Epoch', fontsize=15)
axes.set_ylabel('Loss', fontsize=15)
axes.legend(fontsize=15)
axes.grid(True)

# Setting y-axis limits and intervals
axes.set_ylim(0.5, 4)  # Sets the maximum y-value to 4
axes.yaxis.set_major_locator(plt.MultipleLocator(0.5))  # Sets the interval size on the y-axis
# axes.yaxis.set_major_formatter(FuncFormatter(custom_ticks))
axes.tick_params(axis='x', labelsize=16) 
axes.tick_params(axis='y', labelsize=16)  

# plt.show()
plt.savefig('figures/rs_training_loss_dataset_2.png', dpi=300)

# %%
# Test Loss Comparison
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

axes.plot(epochs, no_sorting_lr001_test_loss, label='w/o SortingLayer Testing Loss, lr=0.001', marker='x', color='blue', linewidth=1)
axes.plot(epochs, sorting_lr001_test_loss, label='w SortingLayer Testing Loss, lr=0.001', marker='o', color='red', linewidth=2)
axes.plot(epochs, no_sorting_lr00005_test_loss, label='w/o SortingLayer Testing Loss lr=0.00005', marker='x', color='green', linewidth=1)
axes.plot(epochs, sorting_lr00005_test_loss, label='w SortingLayer Testing Loss, lr=0.00005', marker='o', color='purple', linewidth=2)
axes.set_title('Testing Loss comparison of RS model w and w/o SortingLayer', fontsize=20)
axes.set_xlabel('Epoch', fontsize=15)
axes.set_ylabel('Loss', fontsize=15)
axes.legend(fontsize=15)
axes.grid(True)

# Setting y-axis limits and intervals
axes.set_ylim(0.5, 4)  # Sets the maximum y-value to 4
axes.yaxis.set_major_locator(plt.MultipleLocator(0.5))  # Sets the interval size on the y-axis
# axes.yaxis.set_major_formatter(FuncFormatter(custom_ticks))
axes.tick_params(axis='x', labelsize=16) 
axes.tick_params(axis='y', labelsize=16)  

# plt.show()
plt.savefig('figures/rs_testing_loss_dataset_2.png', dpi=300)

# %%
# small dataset


small_epochs = list(range(1, 41))
small_no_sorting_train_loss = [5.0080, 2.4082, 1.9289, 1.8334, 1.7489, 1.6853, 1.6237, 1.5761, 1.5199, 1.4714, 1.4232, 1.3563, 1.2913, 1.2205, 1.1443, 1.0602, 0.9811, 0.8740, 0.7830, 0.6593, 0.5660, 0.4834, 0.3980, 0.3208, 0.2834, 0.2200, 0.1642, 0.1331, 0.1051, 0.0821, 0.0666, 0.0492, 0.0362, 0.0265, 0.0184, 0.0143, 0.0113, 0.0088, 0.0070, 0.0060]
small_no_sorting_test_loss = [3.5248, 2.1237, 2.0906, 2.0710, 2.0643, 2.0712, 2.0875, 2.1079, 2.1188, 2.1256, 2.1600, 2.2111, 2.2358, 2.2443, 2.2816, 2.4418, 2.4267, 2.4683, 2.5133, 2.6066, 2.7837, 2.7364, 2.8518, 2.9184, 2.8680, 2.9618, 3.0240, 3.0355, 3.0378, 3.1205, 3.1010, 3.1265, 3.0919, 3.1300, 3.1509, 3.1263, 3.1423, 3.1346, 3.1343, 3.1399]

# %%
# regularization_strength=1.0

small_reg_1_train_loss = [10.7442, 7.9821, 2.9406, 2.3068, 2.1428, 2.1601, 2.1048, 2.0678, 2.0876, 2.0790, 2.0455, 2.1053, 2.1053, 2.0928, 2.0654, 2.0909, 2.0251, 2.0702, 2.0813, 2.0790, 2.0687, 2.1003, 2.0368, 2.0816, 2.0554, 2.0810, 2.0969, 2.0152, 2.0726, 2.0477, 2.0687, 1.9908, 2.0673, 2.0528, 2.0648, 2.0217, 2.0385, 2.0131, 2.0324, 2.0228]
small_reg_1_test_loss = [10.4069, 4.9532, 2.3152, 2.2793, 2.1142, 2.1096, 2.1612, 2.0574, 2.0578, 2.0844, 2.0551, 2.0803, 2.0927, 2.0864, 2.1052, 2.0447, 2.0667, 2.0539, 2.0723, 2.0397, 2.0454, 2.1263, 2.0736, 2.1750, 2.0361, 2.1757, 2.0887, 2.0513, 2.0466, 2.0529, 2.0490, 2.0856, 2.0616, 2.0901, 2.0900, 2.0353, 2.0352, 2.0242, 2.0637, 2.0418]

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

axes.plot(small_epochs, small_no_sorting_train_loss, label='w/o SortingLayer Training Loss', marker='x', color='blue', linewidth=1)
axes.plot(small_epochs, small_reg_1_train_loss, label='w SortingLayer Training Loss, reg=1.0', marker='o', color='red', linewidth=2)
axes.plot(small_epochs, small_reg_05_train_loss, label='w SortingLayer Training Loss, reg=0.5', marker='o', color='green', linewidth=2)
axes.plot(small_epochs, small_reg_02_train_loss, label='w SortingLayer Training Loss, reg=0.2', marker='o', color='purple', linewidth=2)
axes.plot(small_epochs, small_reg_01_train_loss, label='w SortingLayer Training Loss, reg=0.1', marker='o', color='orange', linewidth=2)
axes.set_title('Training Loss of RS model w and w/o SortingLayer for different regularization strengths', fontsize=18)
axes.set_xlabel('Epoch', fontsize=15)
axes.set_ylabel('Loss', fontsize=15)
axes.legend(fontsize=15)
axes.grid(True)

# Setting y-axis limits and intervals
axes.set_ylim(0.5, 4)  # Sets the maximum y-value to 4
axes.yaxis.set_major_locator(plt.MultipleLocator(0.5))  # Sets the interval size on the y-axis
# axes.yaxis.set_major_formatter(FuncFormatter(custom_ticks))
axes.tick_params(axis='x', labelsize=16) 
axes.tick_params(axis='y', labelsize=16)  

# plt.show()
plt.savefig('figures/rs_training_loss_dataset_1.png', dpi=300)

# %%
# Test Loss Comparison
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

axes.plot(small_epochs, small_no_sorting_test_loss, label='w/o SortingLayer Testing Loss', marker='x', color='blue', linewidth=1)
axes.plot(small_epochs, small_reg_1_test_loss, label='w SortingLayer Testing Loss, reg=1.0', marker='o', color='red', linewidth=2)
axes.plot(small_epochs, small_reg_05_test_loss, label='w SortingLayer Testing Loss, reg=0.5', marker='o', color='green', linewidth=2)
axes.plot(small_epochs, small_reg_02_test_loss, label='w SortingLayer Testing Loss, reg=0.2', marker='o', color='purple', linewidth=2)
axes.plot(small_epochs, small_reg_01_test_loss, label='w SortingLayer Testing Loss, reg=0.1', marker='o', color='orange', linewidth=2)
axes.set_title('Testing Loss of RS model w and w/o SortingLayer for different regularization strengths', fontsize=18)
axes.set_xlabel('Epoch', fontsize=15)
axes.set_ylabel('Loss', fontsize=15)
axes.legend(fontsize=15)
axes.grid(True)

# Setting y-axis limits and intervals
axes.set_ylim(0.5, 4)  # Sets the maximum y-value to 4
axes.yaxis.set_major_locator(plt.MultipleLocator(0.5))  # Sets the interval size on the y-axis
# axes.yaxis.set_major_formatter(FuncFormatter(custom_ticks))
axes.tick_params(axis='x', labelsize=16) 
axes.tick_params(axis='y', labelsize=16)  

# plt.show()
plt.savefig('figures/rs_testing_loss_dataset_1.png', dpi=300)
